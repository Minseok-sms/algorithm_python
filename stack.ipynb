# %%
data_stack = list()
data_stack.append(1);
data_stack.append(2);
print(data_stack)
# Out:
# [1, 2]

# %%
data_stack.pop()
# Out:
# 2

# %%
data_stack.pop()
# Out:
# 1

# %%
print(data_stack)
# Out:
# []

# %%
stack_list = list();
def push(data):
    stack_list.append(data);
def pop():
    data = stack_list[-1];
    del stack_list[-1];
    return data;
for index in range(10):
    push(index);
pop()
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
pop()
# Out:
# 8

# %%
st1 = list();
st1.append(1);
st1.append(2);
print(st1);
print(st1.pop());
# Out:
# [1, 2]
# 2
